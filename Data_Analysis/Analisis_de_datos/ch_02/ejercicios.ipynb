# %% [markdown]
# # Ejercicios
#
# Usando el archivo data/parsed.csv y el material de este capítulo, complete los siguientes ejercicios para practicar sus habilidades con pandas:
#
# 1. Encuentre el percentil 95 de la magnitud del terremoto en Japón usando el mb tipo de magnitud.
# 2. Encuentra el porcentaje de terremotos en Indonesia que fueron acompañados de tsunamis.
# 3. Calcular las estadísticas resumidas de los terremotos en Nevada.
# 4. Añade una columna indicando si el terremoto ocurrió en un país o estado de EEUU que se encuentre en el Cinturón de Fuego. Utiliza Alaska, Antártida (busca Antarctic), Bolivia,
# California, Canadá, Chile, Costa Rica, Ecuador, Fiyi, Guatemala, Indonesia, Japón, Islas Kermadec, México (tenga cuidado de no seleccionar Nuevo México), Nueva Zelanda, Perú, Filipinas, Rusia, Taiwán, Tonga y Washington.
# 5. Calcula el número de terremotos en los lugares del Cinturón de Fuego y el número fuera de ellos.
# 6. Calcula el número de tsunamis a lo largo del Cinturón de Fuego.

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('data/parsed.csv')
df.head()
# Out:
#   alert  cdi      code                                             detail  \
# 0   NaN  NaN  37389218  https://earthquake.usgs.gov/fdsnws/event/1/que...
# 1   NaN  NaN  37389202  https://earthquake.usgs.gov/fdsnws/event/1/que...
# 2   NaN  4.4  37389194  https://earthquake.usgs.gov/fdsnws/event/1/que...
# 3   NaN  NaN  37389186  https://earthquake.usgs.gov/fdsnws/event/1/que...
# 4   NaN  NaN  73096941  https://earthquake.usgs.gov/fdsnws/event/1/que...
#
#        dmin  felt    gap           ids   mag magType  ...     status  \
# 0  0.008693   NaN   85.0  ,ci37389218,  1.35      ml  ...  automatic
# 1  0.020030   NaN   79.0  ,ci37389202,  1.29      ml  ...  automatic
# 2  0.021370  28.0   21.0  ,ci37389194,  3.42      ml  ...  automatic
# 3  0.026180   NaN   39.0  ,ci37389186,  0.44      ml  ...  automatic
# 4  0.077990   NaN  192.0  ,nc73096941,  2.16      md  ...  automatic
#
#             time                          title tsunami        type  \
# 0  1539475168010  M 1.4 - 9km NE of Aguanga, CA       0  earthquake
# 1  1539475129610  M 1.3 - 9km NE of Aguanga, CA       0  earthquake
# 2  1539475062610  M 3.4 - 8km NE of Aguanga, CA       0  earthquake
# 3  1539474978070  M 0.4 - 9km NE of Aguanga, CA       0  earthquake
# 4  1539474716050  M 2.2 - 10km NW of Avenal, CA       0  earthquake
#
#                                                types     tz        updated  \
# 0         ,geoserve,nearby-cities,origin,phase-data, -480.0  1539475395144
# 1         ,geoserve,nearby-cities,origin,phase-data, -480.0  1539475253925
# 2  ,dyfi,focal-mechanism,geoserve,nearby-cities,o... -480.0  1539536756176
# 3         ,geoserve,nearby-cities,origin,phase-data, -480.0  1539475196167
# 4  ,geoserve,nearby-cities,origin,phase-data,scit... -480.0  1539477547926
#
#                                                  url parsed_place
# 0  https://earthquake.usgs.gov/earthquakes/eventp...   California
# 1  https://earthquake.usgs.gov/earthquakes/eventp...   California
# 2  https://earthquake.usgs.gov/earthquakes/eventp...   California
# 3  https://earthquake.usgs.gov/earthquakes/eventp...   California
# 4  https://earthquake.usgs.gov/earthquakes/eventp...   California
#
# [5 rows x 27 columns]

# %%
df.columns
# Out:
# Index(['alert', 'cdi', 'code', 'detail', 'dmin', 'felt', 'gap', 'ids', 'mag',
#        'magType', 'mmi', 'net', 'nst', 'place', 'rms', 'sig', 'sources',
#        'status', 'time', 'title', 'tsunami', 'type', 'types', 'tz', 'updated',
#        'url', 'parsed_place'],
#       dtype='object')

# %%
#Ejercicio 1
df.set_index('parsed_place').filter(like='J', axis=0).head(1) #buscamos como esta nombrado Japon
# Out:
#              alert  cdi      code  \
# parsed_place
# Japan          NaN  NaN  1000hbqa
#
#                                                          detail   dmin  felt  \
# parsed_place
# Japan         https://earthquake.usgs.gov/fdsnws/event/1/que...  1.415   NaN
#
#                gap           ids  mag magType  ...  sources    status  \
# parsed_place                                   ...
# Japan         72.0  ,us1000hbqa,  4.6      mb  ...     ,us,  reviewed
#
#                        time                             title  tsunami  \
# parsed_place
# Japan         1539448501800  M 4.6 - 160km NNW of Nago, Japan        0
#
#                     type                         types     tz        updated  \
# parsed_place
# Japan         earthquake  ,geoserve,origin,phase-data,  480.0  1539449501040
#
#                                                             url
# parsed_place
# Japan         https://earthquake.usgs.gov/earthquakes/eventp...
#
# [1 rows x 26 columns]

# %%
df.loc[(df.parsed_place=="Japan") & (df.magType=="mb"),["mag"]].info()#filtramos y comprobamos que no haya nulos
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 50 entries, 67 to 9198
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   mag     50 non-null     float64
# dtypes: float64(1)
# memory usage: 800.0 bytes

# %%
df.loc[(df.parsed_place=="Japan") & (df.magType=="mb"),["mag"]].quantile(0.95) # calculamos el percentil 95
# Out:
# mag    4.9
# Name: 0.95, dtype: float64

# %%
#Ejercicio 2
df.set_index('parsed_place').filter(like='I', axis=0).head(1)
# Out:
#              alert  cdi      code  \
# parsed_place
# Indonesia      NaN  NaN  1000hbtn
#
#                                                          detail   dmin  felt  \
# parsed_place
# Indonesia     https://earthquake.usgs.gov/fdsnws/event/1/que...  3.191   NaN
#
#                gap           ids  mag magType  ...  sources    status  \
# parsed_place                                   ...
# Indonesia     37.0  ,us1000hbtn,  4.7      mb  ...     ,us,  reviewed
#
#                        time                                    title  tsunami  \
# parsed_place
# Indonesia     1539472814760  M 4.7 - 219km SSE of Saparua, Indonesia        0
#
#                     type                         types     tz        updated  \
# parsed_place
# Indonesia     earthquake  ,geoserve,origin,phase-data,  540.0  1539473712040
#
#                                                             url
# parsed_place
# Indonesia     https://earthquake.usgs.gov/earthquakes/eventp...
#
# [1 rows x 26 columns]

# %%
df2=df.loc[(df.parsed_place=="Indonesia"),["tsunami"]]
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 147 entries, 9 to 9212
# Data columns (total 1 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   tsunami  147 non-null    int64
# dtypes: int64(1)
# memory usage: 2.3 KB

# %%
#Porcentaje de terremotos acompañados de tsunami en Indonesia
df2.sum()/df2.count()*100
# Out:
# tsunami    23.129252
# dtype: float64

# %%
#Ejercicio 3
df.set_index('parsed_place').filter(like='N', axis=0).head(1)
# Out:
#              alert  cdi      code  \
# parsed_place
# Nevada         NaN  NaN  00660878
#
#                                                          detail   dmin  felt  \
# parsed_place
# Nevada        https://earthquake.usgs.gov/fdsnws/event/1/que...  0.091   NaN
#
#                  gap           ids  mag magType  ...  sources    status  \
# parsed_place                                     ...
# Nevada        155.59  ,nn00660878,  1.3      ml  ...     ,nn,  reviewed
#
#                        time                                title  tsunami  \
# parsed_place
# Nevada        1539461038285  M 1.3 - 13km E of Hawthorne, Nevada        0
#
#                     type                         types     tz        updated  \
# parsed_place
# Nevada        earthquake  ,geoserve,origin,phase-data, -480.0  1539482691389
#
#                                                             url
# parsed_place
# Nevada        https://earthquake.usgs.gov/earthquakes/eventp...
#
# [1 rows x 26 columns]

# %%
df.loc[(df.parsed_place=="Nevada")].describe()
# Out:
#              cdi        dmin       felt         gap         mag   mmi  \
# count  15.000000  681.000000  15.000000  681.000000  681.000000  1.00
# mean    2.440000    0.166199   2.400000  153.668120    0.500073  2.84
# std     0.501142    0.166228   4.626013   68.735302    0.696710   NaN
# min     2.000000    0.001000   1.000000   29.140000   -0.500000  2.84
# 25%     2.000000    0.053000   1.000000   97.380000   -0.100000  2.84
# 50%     2.200000    0.112000   1.000000  149.140000    0.400000  2.84
# 75%     2.900000    0.233000   1.000000  199.720000    0.900000  2.84
# max     3.300000    1.414000  19.000000  355.910000    2.900000  2.84
#
#               nst         rms         sig          time  tsunami     tz  \
# count  681.000000  681.000000  681.000000  6.810000e+02    681.0  681.0
# mean    12.618209    0.151986   10.970631  1.538314e+12      0.0 -480.0
# std      9.866963    0.084662   19.607150  5.965637e+08      0.0    0.0
# min      3.000000    0.000500    0.000000  1.537247e+12      0.0 -480.0
# 25%      6.000000    0.106900    0.000000  1.537854e+12      0.0 -480.0
# 50%     10.000000    0.146300    2.000000  1.538280e+12      0.0 -480.0
# 75%     16.000000    0.187100   12.000000  1.538821e+12      0.0 -480.0
# max     61.000000    0.863400  129.000000  1.539461e+12      0.0 -480.0
#
#             updated
# count  6.810000e+02
# mean   1.538402e+12
# std    6.010951e+08
# min    1.537307e+12
# 25%    1.537928e+12
# 50%    1.538428e+12
# 75%    1.538878e+12
# max    1.539483e+12

# %% [markdown]
# 4. Añade una columna indicando si el terremoto ocurrió en un país o estado de EEUU que se encuentre en el Cinturón de Fuego. Utiliza Alaska, Antártida (busca Antarctic), Bolivia,
# California, Canadá, Chile, Costa Rica, Ecuador, Fiyi, Guatemala, Indonesia, Japón, Islas Kermadec, México (tenga cuidado de no seleccionar Nuevo México), Nueva Zelanda, Perú, Filipinas, Rusia, Taiwán, Tonga y Washington.

# %%
#Ejercicio 4

#creamos lista con paises/estados pertenecientes a cinturón de fuego
c_fuego=["Alaska","Antarctic","Bolivia","California","Canada","Chile","Costa Rica","Ecuador","Fiji","Guatemala","Indonesia","Japan","Kermadec Islands","Mexico","New Zealand","Peru","Philippines","Russia","Taiwan","Tonga","Washington"]
df["cinturon_fuego"]=df.parsed_place.apply(lambda x: 1 if x in c_fuego else 0) #creamos columna y añadimos 1 si esta en la lista y 0 en caso contrario
df
# Out:
#      alert  cdi        code  \
# 0      NaN  NaN    37389218
# 1      NaN  NaN    37389202
# 2      NaN  4.4    37389194
# 3      NaN  NaN    37389186
# 4      NaN  NaN    73096941
# ...    ...  ...         ...
# 9327   NaN  NaN    73086771
# 9328   NaN  NaN    38063967
# 9329   NaN  NaN  2018261000
# 9330   NaN  NaN    38063959
# 9331   NaN  NaN    38063935
#
#                                                  detail      dmin  felt  \
# 0     https://earthquake.usgs.gov/fdsnws/event/1/que...  0.008693   NaN
# 1     https://earthquake.usgs.gov/fdsnws/event/1/que...  0.020030   NaN
# 2     https://earthquake.usgs.gov/fdsnws/event/1/que...  0.021370  28.0
# 3     https://earthquake.usgs.gov/fdsnws/event/1/que...  0.026180   NaN
# 4     https://earthquake.usgs.gov/fdsnws/event/1/que...  0.077990   NaN
# ...                                                 ...       ...   ...
# 9327  https://earthquake.usgs.gov/fdsnws/event/1/que...  0.018060   NaN
# 9328  https://earthquake.usgs.gov/fdsnws/event/1/que...  0.030410   NaN
# 9329  https://earthquake.usgs.gov/fdsnws/event/1/que...  0.452600   NaN
# 9330  https://earthquake.usgs.gov/fdsnws/event/1/que...  0.018650   NaN
# 9331  https://earthquake.usgs.gov/fdsnws/event/1/que...  0.016980   NaN
#
#         gap             ids   mag magType  ...           time  \
# 0      85.0    ,ci37389218,  1.35      ml  ...  1539475168010
# 1      79.0    ,ci37389202,  1.29      ml  ...  1539475129610
# 2      21.0    ,ci37389194,  3.42      ml  ...  1539475062610
# 3      39.0    ,ci37389186,  0.44      ml  ...  1539474978070
# 4     192.0    ,nc73096941,  2.16      md  ...  1539474716050
# ...     ...             ...   ...     ...  ...            ...
# 9327  185.0    ,nc73086771,  0.62      md  ...  1537230228060
# 9328   50.0    ,ci38063967,  1.00      ml  ...  1537230135130
# 9329  276.0  ,pr2018261000,  2.40      md  ...  1537229908180
# 9330   61.0    ,ci38063959,  1.10      ml  ...  1537229545350
# 9331   39.0    ,ci38063935,  0.66      ml  ...  1537228864470
#
#                                          title  tsunami        type  \
# 0                M 1.4 - 9km NE of Aguanga, CA        0  earthquake
# 1                M 1.3 - 9km NE of Aguanga, CA        0  earthquake
# 2                M 3.4 - 8km NE of Aguanga, CA        0  earthquake
# 3                M 0.4 - 9km NE of Aguanga, CA        0  earthquake
# 4                M 2.2 - 10km NW of Avenal, CA        0  earthquake
# ...                                        ...      ...         ...
# 9327      M 0.6 - 9km ENE of Mammoth Lakes, CA        0  earthquake
# 9328               M 1.0 - 3km W of Julian, CA        0  earthquake
# 9329  M 2.4 - 35km NNE of Hatillo, Puerto Rico        0  earthquake
# 9330             M 1.1 - 9km NE of Aguanga, CA        0  earthquake
# 9331             M 0.7 - 9km NE of Aguanga, CA        0  earthquake
#
#                                                   types     tz        updated  \
# 0            ,geoserve,nearby-cities,origin,phase-data, -480.0  1539475395144
# 1            ,geoserve,nearby-cities,origin,phase-data, -480.0  1539475253925
# 2     ,dyfi,focal-mechanism,geoserve,nearby-cities,o... -480.0  1539536756176
# 3            ,geoserve,nearby-cities,origin,phase-data, -480.0  1539475196167
# 4     ,geoserve,nearby-cities,origin,phase-data,scit... -480.0  1539477547926
# ...                                                 ...    ...            ...
# 9327         ,geoserve,nearby-cities,origin,phase-data, -480.0  1537285598315
# 9328  ,geoserve,nearby-cities,origin,phase-data,scit... -480.0  1537276800970
# 9329                       ,geoserve,origin,phase-data, -240.0  1537243777410
# 9330  ,focal-mechanism,geoserve,nearby-cities,origin... -480.0  1537230211640
# 9331  ,focal-mechanism,geoserve,nearby-cities,origin... -480.0  1537305830770
#
#                                                     url  parsed_place  \
# 0     https://earthquake.usgs.gov/earthquakes/eventp...    California
# 1     https://earthquake.usgs.gov/earthquakes/eventp...    California
# 2     https://earthquake.usgs.gov/earthquakes/eventp...    California
# 3     https://earthquake.usgs.gov/earthquakes/eventp...    California
# 4     https://earthquake.usgs.gov/earthquakes/eventp...    California
# ...                                                 ...           ...
# 9327  https://earthquake.usgs.gov/earthquakes/eventp...    California
# 9328  https://earthquake.usgs.gov/earthquakes/eventp...    California
# 9329  https://earthquake.usgs.gov/earthquakes/eventp...   Puerto Rico
# 9330  https://earthquake.usgs.gov/earthquakes/eventp...    California
# 9331  https://earthquake.usgs.gov/earthquakes/eventp...    California
#
#      cinturon_fuego
# 0                 1
# 1                 1
# 2                 1
# 3                 1
# 4                 1
# ...             ...
# 9327              1
# 9328              1
# 9329              0
# 9330              1
# 9331              1
#
# [9332 rows x 28 columns]
